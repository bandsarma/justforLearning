# %% [markdown]
# # This is just for fun

# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry"]
for fruit in fruits:
    if fruit.startswith("b") or fruit.startswith("d"):
        print(fruit)
# Out:
# banana
# date
